# %% [markdown]
# ## Curse of Dimensionality
#
# Curse of Dimensionality in Machine Learning arises when working with high-dimensional data, leading to increased computational complexity, overfitting, and spurious correlations.
#
# In high-dimensional spaces, data points become sparse, making it challenging to discern meaningful patterns or relationships due to the vast amount of data required to adequately sample the space.
#
# ### Dimensionality Reduction Techniques:
# - **Feature Selection:** Identify and select the most relevant features from the original dataset while discarding irrelevant or redundant ones. This reduces the dimensionality of the data, simplifying the model and improving its efficiency.
# - **Feature Extraction:** Transform the original high-dimensional data into a lower-dimensional space by creating new features that capture the essential information. Techniques such as Principal Component Analysis (PCA) and t-distributed Stochastic Neighbor Embedding (t-SNE) are commonly used for feature extraction.

# %% [markdown]
# ## Principal Component Analysis (PCA)
#
# It used to further reduce the dimensionality of the selected features. It transforms the data into a lower-dimensional space while retaining as much variance as possible. We will keep the columns which has the most variance.
#
# It changes your original features into new features these new features don’t overlap with each other
#
# It finds these by calculating eigenvectors (directions) and eigenvalues (importance) from the covariance matrix. PCA selects the top components with the highest eigenvalues and projects the data onto them simplify the dataset.
#
# ### Steps for PCA
# **Step 1: Standardize the Data**
# Different features may have different units and scales like salary vs. age. To compare them fairly PCA first standardizes the data by making each feature have Zero mean
#
# **Step 2: Calculate Covariance Matrix**
# Next PCA calculates the covariance matrix to see how features relate to each other whether they increase or decrease together.
#
# **Step 3: Find the Principal Components**
# PCA identifies new axes where the data spreads out the most:
#
# 1st Principal Component (PC1): The direction of maximum variance (most spread).
# 2nd Principal Component (PC2): The next best direction, perpendicular to PC1 and so on.
# These directions come from the eigenvectors of the covariance matrix and their importance is measured by eigenvalues. For a square matrix A an eigenvector X (a non-zero vector) and its corresponding eigenvalue λ satisfy:
#
# AX=λX
#
# This means:
#
# When A acts on X it only stretches or shrinks X by the scalar λ.
# The direction of X remains unchanged hence eigenvectors define "stable directions" of A.
# Eigenvalues help rank these directions by importance.
#
# **Step 4: Pick the Top Directions & Transform Data**
# After calculating the eigenvalues and eigenvectors PCA ranks them by the amount of information they capture. We then:
#
# Select the top k components hat capture most of the variance like 95%.
# Transform the original dataset by projecting it onto these top components.
# This means we reduce the number of features (dimensions) while keeping the important patterns in the data.
#
# **Visualizing Eigen vectors and Eigen values** <a>https://www.geogebra.org/m/YCZa8TAH</a>
#
# **A geometric interpretation of the covariance matrix** <br>
# <a>https://www.visiondummy.com/2014/04/geometric-interpretation-covariance-matrix/#:~:text=covariance%20matrix%20captures%20the%20spread%20of%20N%2Ddimensional%20data.&text=Figure%203.,is%20captured%20by%20the%20variance</a>

# %% [markdown]
# ## 📊 Covariance and Covariance Matrix in Machine Learning
#
# ### 🔹 What is Covariance?
# Covariance measures how **two variables vary together** — whether they increase or decrease in relation to each other.
#
#
# ### 🔍 Interpretation
# | Covariance Value | Interpretation |
# |------------------:|---------------|
# | \( > 0 \) | \( X \) and \( Y \) increase together (positive relationship) |
# | \( < 0 \) | \( X \) increases when \( Y \) decreases (negative relationship) |
# | \( = 0 \) | No linear relationship between \( X \) and \( Y \) |
#
# > Covariance shows **direction of relationship**, but not its **strength** (unlike correlation, which is normalized between -1 and 1).
#
# ---
#
# ### 🧮 Covariance Matrix
# we could calculate the variance \sigma(x,x) in the x-direction and the variance \sigma(y,y) in the y-direction. However, the horizontal spread and the vertical spread of the data does not explain the clear diagonal correlation. Figure 2 clearly shows that on average, if the x-value of a data point increases, then also the y-value increases, resulting in a positive correlation. This correlation can be captured by extending the notion of variance to what is called the ‘covariance’ of the data:
#
# (2) \begin{equation*} \sigma(x,y) = \mathbb{E}[ (x - \mathbb{E}(x)) (y - \mathbb{E}(y))] \end{equation*}
#
# For 2D data, we thus obtain \sigma(x,x), \sigma(y,y), \sigma(x,y) and \sigma(y,x). These four values can be summarized in a matrix, called the covariance matrix:
#
# (3) \begin{equation*} \Sigma = \begin{bmatrix} \sigma(x,x) & \sigma(x,y) \\[0.3em] \sigma(y,x) & \sigma(y,y) \\[0.3em] \end{bmatrix} \end{equation*}
#
# If x is positively correlated with y, y is also positively correlated with x. In other words, we can state that \sigma(x,y) = \sigma(y,x). Therefore, the covariance matrix is always a symmetric matrix with the variances on its diagonal and the covariances off-diagonal. Two-dimensional normally distributed data is explained completely by its mean and its 2\times 2 covariance matrix. Similarly, a 3 \times 3 covariance matrix is used to capture the spread of three-dimensional data, and a N \times N covariance matrix captures the spread of N-dimensional data.
#
# ---
#
# ### 🧠 Intuition in ML
# - Covariance measures **how features move together** — crucial for understanding **feature redundancy** and **correlation**.
# - Large covariances between features → **multicollinearity** (redundant information).
# - Used to **capture feature relationships** and **reduce dimensionality** (e.g., PCA).
#
# ---
#
# ### ⚙️ Example (3 features)
# \[
# \Sigma =
# \begin{bmatrix}
# \text{Var}(X_1) & \text{Cov}(X_1,X_2) & \text{Cov}(X_1,X_3) \\
# \text{Cov}(X_2,X_1) & \text{Var}(X_2) & \text{Cov}(X_2,X_3) \\
# \text{Cov}(X_3,X_1) & \text{Cov}(X_3,X_2) & \text{Var}(X_3)
# \end{bmatrix}
# \]
#
# This matrix is **symmetric**, since \( \text{Cov}(X_i, X_j) = \text{Cov}(X_j, X_i) \).
#
# ---
#
# ### 🔬 Why Covariance Matters in Machine Learning
# - **Principal Component Analysis (PCA):**
#   Eigenvectors of the covariance matrix define new orthogonal feature directions (principal components).
# - **Multivariate Gaussian Modeling:**
#   Covariance matrix defines **shape and orientation** of the Gaussian distribution in feature space.
# - **Portfolio Optimization / Risk Analysis:**
#   Covariance quantifies **joint variability** between assets/features.
# - **Feature Selection:**
#   Identifies correlated features → helps reduce redundancy.
#
# ---
#
# ### ⚖️ Key Points to Remember
# | Concept | Description |
# |----------|-------------|
# | **Covariance** | Measures joint variability between two variables |
# | **Covariance Matrix** | Generalization for multiple variables |
# | **Symmetric** | \( \Sigma_{ij} = \Sigma_{ji} \) |
# | **Diagonal entries** | Represent individual feature variances |
# | **Used in** | PCA, Gaussian models, feature correlation analysis |
# | **Unit-dependent** | Not normalized; affected by feature scale |
#
# ---
#
# ### ⚠️ Limitations
# - **Scale-sensitive:** If one feature is in meters and another in millimeters, covariance values can mislead — hence **standardization** is often required.
# - **Interpretation complexity:** Covariance gives direction but not magnitude of relationship (for that, use **correlation**).
# - **Multicollinearity issues:** Highly correlated features can cause instability in regression models.
#
# ---
#
# > 💡 **In short:**
# > Covariance measures *how features move together*.
# > The **covariance matrix** is its multidimensional extension — a cornerstone in **PCA**, **Gaussian models**, and **feature correlation analysis**.

# %% [markdown]
# ### PCA without sklearn

# %%
import pandas as pd
import numpy as np

np.random.seed(23)

# %%
mu_vec1 = np.array([0,0,0])
cov_mat1 = np.array([[1,0,0], [0,1,0], [0,0,1]])
class1_sample = np.random.multivariate_normal(mu_vec1, cov_mat1, 20)

df = pd.DataFrame(class1_sample, columns=['feature1', 'feature2', 'feature3'])
df['target'] = 1

mu_vec2 = np.array([1,1,1])
cov_mat2 = np.array([[1,0,0],[0,1,0],[0,0,1]])
class2_sample = np.random.multivariate_normal(mu_vec2, cov_mat2, 20)

df1 = pd.DataFrame(class2_sample,columns=['feature1','feature2','feature3'])

df1['target'] = 0

df = pd.concat([df, df1], axis=0)

df = df.sample(40)
df.head()
# Out:
#     feature1  feature2  feature3  target
# 15  0.904913 -0.155969  0.183063       0
# 4  -0.310621 -0.182088  2.481469       0
# 10  0.082238 -0.775645 -0.263904       1
# 14 -0.561595  3.092138  1.311076       0
# 19 -0.893922  0.915124 -0.842607       1

# %%
import plotly.io as pio
pio.renderers.default = "notebook_connected"

# %%
import plotly.express as px
#y_train_trf = y_train.astype(str)
fig = px.scatter_3d(df, x=df['feature1'], y=df['feature2'], z=df['feature3'],
              color=df['target'].astype('str'))
fig.update_traces(marker=dict(size=12,
                              line=dict(width=2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="29034108-3bf4-499c-89d0-c77bee3c9886" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("29034108-3bf4-499c-89d0-c77bee3c9886")) {                    Plotly.newPlot(                        "29034108-3bf4-499c-89d0-c77bee3c9886",                        [{"hovertemplate":"color=0\u003cbr\u003efeature1=%{x}\u003cbr\u003efeature2=%{y}\u003cbr\u003efeature3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#636efa","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":12},"mode":"markers","name":"0","scene":"scene","showlegend":true,"x":{"dtype":"f8","bdata":"VYIGEgz17D8oB8HsOOHTv7i6\u002fJeV+OG\u002fvyD8Hb4W+T9wfFvwNdT0P9KNxJSaeuW\u002fVkaABrPf+j\u002fYZsyvdtqxP4Bq\u002fm7OHo6\u002frqmyjXMa4T+MI5yIsanYPxA2f8U1SeM\u002f2NJPdlvB+D+EOmPhocT5P+WZgyIUa+U\u002fp\u002fJLWGmkBUA\u002fSr7vS+4AQP4RuMMDDtA\u002fBGZfrIkf9j+\u002fBUDsPSf1Pw=="},"y":{"dtype":"f8","bdata":"eMDCOMn2w79AHlRxqk7Hv3xGy\u002fyyvAhACnH20WBX7j+oDkonXq77PzugceMv6+8\u002fLCkK1C9L9T\u002fw6VdA2oviP5yRlov\u002fn+Y\u002fsz6BZoLZ9T9eFL+ZdTUFQMjhoXbK8uM\u002fUJDltWGg2r9In7IdA4rEP+wLHpYY5dO\u002fmKzb+4sZAECYBJuzwRrCPwjgHjir6ABABNEe+xP9\u002fT+FzzkdXN\u002fvPw=="},"z":{"dtype":"f8","bdata":"3KZ4HJluxz\u002fuWBOLDNoDQInkgVUq+vQ\u002f2GSfmyOA3T8+zhGq1KrwPwoeoefJg98\u002fENRIlpbq7b+QA0I5Xw3qP7CLKLBlZLe\u002fEnTz9j0h+z\u002fTOSOg7njwP3I7sykU9OE\u002fwasqaekB5j+AS2dWtY\u002f8P8RwIqepCvY\u002fGCdi+m+32z\u002fQpvUfAnzov3H+xNals\u002fk\u002fdrfswjvxCUDfVM9XayD8Pw=="},"type":"scatter3d"},{"hovertemplate":"color=1\u003cbr\u003efeature1=%{x}\u003cbr\u003efeature2=%{y}\u003cbr\u003efeature3=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1","marker":{"color":"#EF553B","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":12},"mode":"markers","name":"1","scene":"scene","showlegend":true,"x":{"dtype":"f8","bdata":"JpIGy4gNtT+1XXXuApvsv5CZdlpNveK\u002fSlg\u002fKmdPxb8r5W5hPFzTv938p\u002foHXuW\u002fWOVHA4yV379UZo0mc8akv5miWoRkLsw\u002fVNMwRA849j9jv+i5n33xv9CVmB4sSus\u002f\u002fdrw3YMLAEAV+iHPjmjhvxgrovGs0+A\u002fTeGwc8l3+7\u002f94UsqRo39vzHglhzu1dC\u002f3FvHNxnJmb+QvIK7BCL1vw=="},"y":{"dtype":"f8","bdata":"QP9RjRTS6L9LiUhasUjtP+Y5ODnwzcm\u002fOW3PKoR82T+oqIoOnqHrP77+mcQTswPAHMxJol\u002ff2D9lLaEXnhzwP1dQL6Cu5d0\u002foMBvEVf+9D\u002fs7wK2gnbaP5drE0W51QLA5a\u002fnaS90or9DRsriCCrzv6i9fIiWPLi\u002fcIPh55a4\u002fb9m95\u002fOCv3av9bjdVgg3\u002fu\u002foPhbUjQxzT9vuSwPjaHivw=="},"z":{"dtype":"f8","bdata":"fAA\u002fMM7j0L8ZDYo\u002fo\u002fbqv+DzJ9Qj5M4\u002fQPfawAqSub8obrbGDtj6v6LSFDbLEdS\u002fsXJTEcmO6D+fdfQRFIzpP3VKyDQap+c\u002f8bqlQ3nw3z87Aj\u002fNfPHqv6PppAv9hsE\u002fp4\u002ftkBKu2b8Ykg20WrLYvyR\u002fAw3jswJAylMODh5qyb83qFr0\u002fQvoPycRWYaDL9q\u002fGhtgpm6y5b8wU\u002fJ+X9TVvw=="},"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"# ...

# %%
# Step 1 - Apply standard scaling - Zero mean
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df.iloc[:,0:3] = scaler.fit_transform(df.iloc[:,0:3])

# %%
# Step 2 - Find Covariance Matrix
covariance_matrix = np.cov([df.iloc[:,0], df.iloc[:,1], df.iloc[:,2]])
print('Covariance Matrix:\n', covariance_matrix)
# Out:
# Covariance Matrix:
#  [[1.02564103 0.3200422  0.21843387]
#  [0.3200422  1.02564103 0.3388328 ]
#  [0.21843387 0.3388328  1.02564103]]

# %%
# Step 3 - Finding EV and EVs
eigen_values, eigen_vectors = np.linalg.eig(covariance_matrix)
eigen_values, eigen_vectors
# Out:
# (array([1.61346778, 0.80783819, 0.65561711]),
#  array([[-0.54681182, -0.74118538,  0.38941117],
#         [-0.62124854,  0.04737873, -0.78217997],
#         [-0.56129055,  0.66962638,  0.48636758]]))

# %%
# %matplotlib inline

import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import proj3d
from matplotlib.patches import FancyArrowPatch

class Arrow3D(FancyArrowPatch):
    def __init__(self, xs, ys, zs, *args, **kwargs):
        super().__init__((0, 0), (0, 0), *args, **kwargs)
        self._verts3d = xs, ys, zs

    def draw(self, renderer):
        xs3d, ys3d, zs3d = self._verts3d
        xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, self.axes.get_proj())
        self.set_positions((xs[0], ys[0]), (xs[1], ys[1]))
        super().draw(renderer)

    # <-- This is the piece Matplotlib >=3.6 expects
    def do_3d_projection(self, renderer=None):
        xs3d, ys3d, zs3d = self._verts3d
        xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, self.axes.get_proj())
        self.set_positions((xs[0], ys[0]), (xs[1], ys[1]))
        # Return a depth value for z-ordering (any representative z works)
        return np.min(zs)

# ---- plotting ----
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111, projection='3d')

ax.plot(df['feature1'], df['feature2'], df['feature3'], 'o', markersize=8, color='blue', alpha=0.2)

mx, my, mz = df['feature1'].mean(), df['feature2'].mean(), df['feature3'].mean()
ax.plot([mx], [my], [mz], 'o', markersize=10, color='red', alpha=0.5)

# If eigen_vectors are directions, scale & anchor them at the mean:
scale = 1.0  # adjust to taste
for v in eigen_vectors.T:
    x_end, y_end, z_end = mx + scale*v[0], my + scale*v[1], mz + scale*v[2]
    a = Arrow3D([mx, x_end], [my, y_end], [mz, z_end],
                mutation_scale=20, lw=3, arrowstyle="-|>", color="r")
    ax.add_artist(a)

ax.set_xlabel('x_values'); ax.set_ylabel('y_values'); ax.set_zlabel('z_values')
plt.title('Eigenvectors')
plt.show()

# %%
pc = eigen_vectors[0:2]
pc
# Out:
# array([[-0.54681182, -0.74118538,  0.38941117],
#        [-0.62124854,  0.04737873, -0.78217997]])

# %%
transformed_df = np.dot(df.iloc[:,0:3],pc.T)
new_df = pd.DataFrame(transformed_df,columns=['PC1','PC2'])
new_df['target'] = df['target'].values
new_df.head()
# Out:
#         PC1       PC2  target
# 0 -0.104856 -0.148477       0
# 1  1.404913 -1.186525       0
# 2  0.523017  0.647420       1
# 3 -0.886740 -0.024243       0
# 4 -0.215733  1.722222       1

# %%
new_df['target'] = new_df['target'].astype('str')
fig = px.scatter(x=new_df['PC1'],
                 y=new_df['PC2'],
                 color=new_df['target'],
                 color_discrete_sequence=px.colors.qualitative.G10
                )

fig.update_traces(marker=dict(size=12,
                              line=dict(width=2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="91c138f9-048d-4db6-8e16-f88e3a078287" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("91c138f9-048d-4db6-8e16-f88e3a078287")) {                    Plotly.newPlot(                        "91c138f9-048d-4db6-8e16-f88e3a078287",                        [{"hovertemplate":"color=0\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#3366CC","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":12},"mode":"markers","name":"0","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"yURR\u002fNTXur+t5VY5hnr2Pzhw81otYOy\u002fRwQ58DQe8L\u002fkgcXUnvjxvwyHRt6uBcA\u002fWl9bqcEu\u002fb9yN0qZhl++P3QvdUFUe9C\u002fxTKysoG70L\u002fJojVe1Wnzv57F4IBlwNG\u002fIQAIJ1Q5tr+DFY1YGNiqv1ivK9cH+eE\u002feISia+b1AcCb\u002frGI5D\u002f0vwH2mSIoPuO\u002foOIQzsHT2r\u002f1YGw6CNXavw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"ebTBjEkBw79vSliaAfzyv5Arcd0z05i\u002f8Sk7v7OH5r8A6KJWjLbuv32JUgQZl+I\u002fZqGSBOSZ0z\u002fxZMlmNLW8v+1qiEg5KuQ\u002fNR5qybJd8L995swQq1LYv45Yt06BVs2\u002fP5an10tX7b\u002fTtWIVTT\u002f8v4pFoBfSlu2\u002f6cnG7Jnj9L8SkDcwGKK\u002fv24D4RwEV+i\u002fzKmFalpkBcARQYPeBrX4vw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"color=1\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1","marker":{"color":"#DC3912","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":12},"mode":"markers","name":"1","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"+AT5bY684D+x6Qv6IJ3Lv7oZ4qFwvOY\u002f158TyuDYbj+Bffpc+7zpv0zHlezxiP4\u002fzV4VjIQu4D8AXtCCzb22v3D0kzKAtrQ\u002fmVDQeyfu8b9ovKjENk7IP16KN8\u002f2t\u002fM\u002fWE0yV7\u002fX7r+sN46IftvwP0Po+9ABx+s\u002fViMnNwgBAUA\u002fBzZDmfP6P56jXiy5qvM\u002f9ABkH0qmx7\u002fqE8ghipDxPw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"Zy3qG6u35D9va4pvOI77PzFMs2h0neU\u002f3ZD8fz7T5j8TMNm\u002fvRMAQBOZhMet7PA\u002ffTrKEFVTzz9FwD7uIbeTv0obSUfS2sK\u002faMsNMyeo479ERWBaRxn9P+iAS\u002fSOfcW\u002fpYI+FkHo1b\u002fg\u002fo9M9W3xP41dIPHm\u002fvi\u002f4AUX+D+y+T\u002ffLsj70T\u002fwP8UZRg8xge0\u002fHKCuMlwE8T+qnY2KAIX4Pw=="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"# ...
